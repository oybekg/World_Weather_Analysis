# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# finschhafen pg
# kulhudhuffushi mv
# tunceli tr
# torbay ca
# tandalti sd
# wawa ca
# bluff nz
# butaritari ki
# gazojak tm
# namwala zm
# auki sb
# albany au
# caravelas br
# ribeira grande pt
# severo-kurilsk ru
# saint george bm
# puerto ayora ec
# airai pw
# luderitz na
# partenit ua
# cidreira br
# clarksburg us
# souillac mu
# airai pw
# ushuaia ar
# butaritari ki
# punta arenas cl
# grand river south east mu
# santa marta de tormes es
# hambantota lk
# rikitea pf
# saryagash kz
# illoqqortoormiut gl
# nome us
# puerto ayora ec
# rawson ar
# belo oriente br
# rikitea pf
# mataura pf
# tuktoyaktuk ca
# cabo san lucas mx
# tuktoyaktuk ca
# banda aceh id
# port elizabeth za
# new norfolk au
# rikitea pf
# tiksi ru
# yellowknife ca
# conakry gn
# dikson ru
# olot uz
# pundaguitan ph
# tasiilaq gl
# mataura pf
# port shepstone za
# puerto ayora ec
# hilo us
# narsaq gl
# ust-maya ru
# ushuaia ar
# saint-philippe re
# talcahuano cl
# lucea jm
# east london za
# half moon bay us
# arraial do cabo br
# vaini to
# fortuna us
# ushuaia ar
# san quintin mx
# albany au
# hermanus za
# mataura pf
# rikitea pf
# worland us
# ierapetra gr
# butaritari ki
# mys shmidta ru
# vaini to
# logan lake ca
# maragheh ir
# hobart au
# rikitea pf
# am timan td
# kodar in
# sept-iles ca
# ixtapa mx
# hermanus za
# puerto ayora ec
# taolanaro mg
# cockburn town tc
# punta arenas cl
# sao joao da barra br
# rikitea pf
# ngukurr au
# tabiauea ki
# luderitz na
# urambo tz
# bluff nz
# pangnirtung ca
# tsihombe mg
# lompoc us
# tsihombe mg
# rikitea pf
# bulungu cd
# nanakuli us
# cockburn town tc
# noshiro jp
# albany au
# bredasdorp za
# albany au
# east london za
# punta arenas cl
# vaini to
# vila velha br
# maragogi br
# mys shmidta ru
# yellowknife ca
# shiggaon in
# grand river south east mu
# dehui cn
# el alto pe
# mataura pf
# roald no
# cape town za
# cape town za
# allende mx
# nenjiang cn
# zvishavane zw
# granby ca
# norman wells ca
# souillac mu
# namibe ao
# rikitea pf
# la ronge ca
# saskylakh ru
# georgetown sh
# mar del plata ar
# cape town za
# ushuaia ar
# guayaramerin bo
# eureka us
# barrow us
# port alfred za
# richards bay za
# ust-nera ru
# dingle ie
# vaitupu wf
# karpogory ru
# ostrovnoy ru
# pundaguitan ph
# port elizabeth za
# cidreira br
# salalah om
# mahebourg mu
# puerto ayora ec
# illoqqortoormiut gl
# tuktoyaktuk ca
# barrow us
# fairbanks us
# puerto ayacucho ve
# avarua ck
# cidreira br
# grand river south east mu
# xining cn
# nanortalik gl
# rikitea pf
# avera pf
# rikitea pf
# ushuaia ar
# ushuaia ar
# labuan my
# trinidad cu
# dingli mt
# bluff nz
# hermanus za
# qaanaaq gl
# butaritari ki
# ribeira grande pt
# port alfred za
# vardo no
# santa maria cv
# laerdalsoyri no
# vaini to
# semey kz
# adrar dz
# taoudenni ml
# hilo us
# ushuaia ar
# qaqortoq gl
# alexandria eg
# saint george bm
# tsihombe mg
# toliary mg
# punta arenas cl
# bambous virieux mu
# klaksvik fo
# sao filipe cv
# poum nc
# pamekasan id
# port-gentil ga
# san buenaventura mx
# taicheng cn
# eureka us
# la ligua cl
# new norfolk au
# barrow us
# dunedin nz
# san patricio mx
# illoqqortoormiut gl
# rikitea pf
# arraial do cabo br
# atuona pf
# alice springs au
# mwinilunga zm
# holiday us
# asbe teferi et
# nome us
# tasiilaq gl
# port alfred za
# balikpapan id
# cape town za
# albany au
# tuktoyaktuk ca
# albany au
# atagay ru
# tasiilaq gl
# sao jose da coroa grande br
# canico pt
# nizhneyansk ru
# kapaa us
# tuatapere nz
# mataura pf
# hilo us
# busselton au
# ushuaia ar
# dikson ru
# kaitangata nz
# albany au
# atuona pf
# hithadhoo mv
# les cayes ht
# saposoa pe
# khatanga ru
# svetlaya ru
# nanortalik gl
# busselton au
# vila velha br
# nuevo progreso mx
# naqadeh ir
# bluff nz
# ushuaia ar
# aflu dz
# bluff nz
# puerto ayora ec
# santiago del estero ar
# port hedland au
# bowen au
# cabo san lucas mx
# luderitz na
# castro cl
# anchorage us
# mataura pf
# kapaa us
# bluff nz
# altay cn
# avera pf
# taolanaro mg
# rikitea pf
# punta arenas cl
# mys shmidta ru
# horta pt
# hay river ca
# vallenar cl
# barentsburg sj
# anloga gh
# luderitz na
# saint george bm
# rikitea pf
# qaanaaq gl
# aksha ru
# kaeo nz
# sentyabrskiy ru
# keuruu fi
# saint-philippe re
# raichur in
# busselton au
# mulege mx
# ribeira grande pt
# taolanaro mg
# puerto ayora ec
# faanui pf
# port elizabeth za
# shushtar ir
# avarua ck
# bethel us
# albany au
# clyde river ca
# codrington ag
# usinsk ru
# cape town za
# dingle ie
# khatanga ru
# redmond us
# rikitea pf
# rikitea pf
# albany au
# mar del plata ar
# chepen pe
# kodiak us
# new norfolk au
# kununurra au
# atuona pf
# caravelas br
# kloulklubed pw
# oussouye sn
# bluff nz
# laizhou cn
# ushuaia ar
# hasaki jp
# marck fr
# torbay ca
# puerto escondido mx
# hilo us
# porto novo cv
# mataura pf
# punta arenas cl
# kapaa us
# coquimbo cl
# saskylakh ru
# port alfred za
# butaritari ki
# san cristobal ec
# buzmeyin tm
# hobart au
# susangerd ir
# coquimbo cl
# jiaxing cn
# mar del plata ar
# ruatoria nz
# grand gaube mu
# yellowknife ca
# fairbanks us
# geraldton au
# vega de alatorre mx
# hermanus za
# tiksi ru
# erdenet mn
# nikolskoye ru
# matagami ca
# vaini to
# tiksi ru
# beringovskiy ru
# ushuaia ar
# lata sb
# vysokogornyy ru
# bredasdorp za
# bengkulu id
# mys shmidta ru
# hobart au
# grand river south east mu
# maple creek ca
# hermanus za
# krasnoselkup ru
# albany au
# saint-philippe re
# jining cn
# tsihombe mg
# saskylakh ru
# mar del plata ar
# rikitea pf
# salalah om
# bluff nz
# voznesenye ru
# sola vu
# jalu ly
# tasiilaq gl
# mataura pf
# barentsburg sj
# ushuaia ar
# busselton au
# tuktoyaktuk ca
# tuatapere nz
# qaanaaq gl
# xuddur so
# kapaa us
# hermanus za
# jamestown sh
# saint-philippe re
# mehamn no
# nome us
# mataura pf
# avarua ck
# vaini to
# vaini to
# nsanje mw
# mezen ru
# isperih bg
# avarua ck
# lappeenranta fi
# ballina au
# mahebourg mu
# whitecourt ca
# sussex ca
# reynosa mx
# hermanus za
# chokurdakh ru
# madawaska us
# kapaa us
# vaini to
# kapaa us
# carnarvon au
# qaanaaq gl
# castro cl
# bargal so
# taoudenni ml
# kapaa us
# ushuaia ar
# maniitsoq gl
# namibe ao
# bluff nz
# chokurdakh ru
# nome us
# kainantu pg
# nizhneyansk ru
# punta arenas cl
# richards bay za
# grand river south east mu
# butaritari ki
# kaitangata nz
# bathsheba bb
# vao nc
# khatanga ru
# chipinge zw
# albany au
# margate za
# mataura pf
# palkino ru
# albany au
# bure et
# mizdah ly
# hilo us
# hilo us
# hobart au
# kapaa us
# portland au
# bathsheba bb
# atuona pf
# burica pa
# ahipara nz
# kahului us
# acarau br
# provideniya ru
# kresek id
# morro bay us
# albany au
# ribeira brava pt
# praia cv
# jelenia gora pl
# bluff nz
# chapais ca
# marsh harbour bs
# barra do garcas br
# san carlos de bariloche ar
# jamestown sh
# mar del plata ar
# bredasdorp za
# koluszki pl
# mataura pf
# rikitea pf
# faanui pf
# sinop tr
# nikolskoye ru
# westport ie
# busko-zdroj pl
# yellowknife ca
# lorengau pg
# codrington ag
# yellowknife ca
# avarua ck
# kaitangata nz
# amderma ru
# bredasdorp za
# kaitangata nz
# bilma ne
# jamestown sh
# agua dulce mx
# atuona pf
# carnarvon au
# ushuaia ar
# coquimbo cl
# sentyabrskiy ru
# hilo us
# ushuaia ar
# punta arenas cl
# faanui pf
# ulles hu
# saint-philippe re
# ushuaia ar
# ushuaia ar
# punta arenas cl
# san cristobal ec
# klaksvik fo
# arraial do cabo br
# leh in
# alofi nu
# rikitea pf
# abnub eg
# barrow us
# cananeia br
# qaanaaq gl
# fortuna us
# mataura pf
# busselton au
# santa rita ve
# atuona pf
# bluff nz
# bredasdorp za
# qaanaaq gl
# constitucion mx
# thompson ca
# chikhli in
# upernavik gl
# ushuaia ar
# albany au
# mar del plata ar
# thompson ca
# walvis bay na
# sentyabrskiy ru
# palabuhanratu id
# kaeo nz
# atuona pf
# ushuaia ar
# barentsburg sj
# hargeysa so
# luderitz na
# nyrob ru
# sitka us
# toamasina mg
# paamiut gl
# raga sd
# jibuti dj
# inderborskiy kz
# talnakh ru
# hobart au
# altay cn
# grindavik is
# puerto ayora ec
# viedma ar
# tasco co
# quang ngai vn
# puerto ayora ec
# san carlos py
# saint-philippe re
# lebu cl
# upernavik gl
# mae sai th
# innisfail au
# clyde river ca
# goderich sl
# faya td
# taolanaro mg
# howard springs au
# hobart au
# deputatskiy ru
# talnakh ru
# ust-omchug ru
# hasaki jp
# kapaa us
# ahipara nz
# garissa ke
# upernavik gl
# qaanaaq gl
# hobart au
# lagoa santa br
# vohibinany mg
# tiksi ru
# ponta do sol pt
# mataura pf
# morros br
# mount gambier au
# tiksi ru
# santa maria cv
# busselton au
# barrow us
# lavrentiya ru
# huanren cn
# ribeira grande pt
# qaanaaq gl
# rikitea pf
# myitkyina mm
# rikitea pf
# rikitea pf
# orbetello it
# puerto ayora ec
# palabuhanratu id
# broome au
# kenai us
# omboue ga
# castro cl
# muros es
# rikitea pf
# ushuaia ar
# zambezi zm
# talnakh ru
# znamenskoye ru
# tabou ci
# sarangani ph
# dwarka in
# erzin ru
# georgetown sh
# fort-shevchenko kz
# butaritari ki
# riberalta bo
# dikson ru
# kapaa us
# kapaa us
# san jose gt
# ushuaia ar
# barlinek pl
# kodiak us
# isiro cd
# mildura au
# redlands us
# cape town za
# fairbanks us
# padang id
# verkh-suetka ru
# kropotkin ru
# bluff nz
# new norfolk au
# mahebourg mu
# mar del plata ar
# port macquarie au
# mataura pf
# vaini to
# rikitea pf
# barrow us
# conway us
# asbe teferi et
# coahuayana mx
# dikson ru
# nouadhibou mr
# berdigestyakh ru
# ushuaia ar
# busselton au
# mataura pf
# rikitea pf
# sao filipe cv
# puerto ayacucho ve
# vaitupu wf
# ribeira grande pt
# kamenskoye ru
# shimoda jp
# sainte-maxime fr
# solwezi zm
# laguna br
# vestmannaeyjar is
# dekar bw
# bengkulu id
# atuona pf
# sangar ru
# lieksa fi
# nyurba ru
# havoysund no
# atuona pf
# susehri tr
# illoqqortoormiut gl
# bredasdorp za
# taebla ee
# rikitea pf
# ushuaia ar
# mataura pf
# sao gabriel da cachoeira br
# antofagasta cl
# ribeira grande pt
# nikolskoye ru
# leh in
# katsuura jp
# vardo no
# cape town za
# bluff nz
# taolanaro mg
# belushya guba ru
# albany au
# yalutorovsk ru
# maputo mz
# batagay-alyta ru
# castro cl
# bubaque gw
# richards bay za
# busselton au
# busselton au
# palabuhanratu id
# nikolskoye ru
# tambura sd
# carnarvon au
# mys shmidta ru
# saint george bm
# mataura pf
# mataura pf
# akhtanizovskaya ru
# deputatskiy ru
# lagoa pt
# avarua ck
# touros br
# saint-philippe re
# cape town za
# rikitea pf
# mount gambier au
# nikolskoye ru
# kapaa us
# hervey bay au
# ushuaia ar
# ushuaia ar
# rikitea pf
# bluff nz
# hobart au
# saint-philippe re
# saskylakh ru
# samusu ws
# atuona pf
# aksarka ru
# mataura pf
# clyde river ca
# guerrero negro mx
# ushuaia ar
# bengkulu id
# punta arenas cl
# eyl so
# saskylakh ru
# cape town za
# gat ly
# port alfred za
# ushuaia ar
# rikitea pf
# fortuna us
# lorengau pg
# rikitea pf
# attawapiskat ca
# albany au
# springbok za
# lagunas pe
# new norfolk au
# albany au
# fortuna us
# iquique cl
# flin flon ca
# zhuhai cn
# thompson ca
# albany au
# punta arenas cl
# saint-pierre pm
# bluff nz
# rikitea pf
# jamestown sh
# khonuu ru
# east london za
# kodiak us
# puerto ayora ec
# bathsheba bb
# vila velha br
# vaitupu wf
# hermanus za
# rikitea pf
# hervey bay au
# barentsburg sj
# bonthe sl
# amderma ru
# verkhoyansk ru
# taolanaro mg
# georgetown sh
# ushuaia ar
# east london za
# attawapiskat ca
# gornji milanovac rs
# cherskiy ru
# airai pw
# vondrozo mg
# mana gf
# saskylakh ru
# schroeder br
# vanavara ru
# phan thiet vn
# taolanaro mg
# nikolskoye ru
# rikitea pf
# port elizabeth za
# esperance au
# east london za
# vega de alatorre mx
# rikitea pf
# tyret pervaya ru
# jamestown sh
# leningradskiy ru
# cherskiy ru
# alice springs au
# hobart au
# sechura pe
# saint-philippe re
# punta arenas cl
# akdepe tm
# guiyang cn
# east london za
# castro cl
# umm ruwabah sd
# rio grande br
# bathsheba bb
# tasiilaq gl
# hamilton bm
# carnarvon au
# nova olimpia br
# busselton au
# hermanus za
# new norfolk au
# astana kz
# monster nl
# hay river ca
# kahului us
# ambunti pg
# jodoigne be
# codrington ag
# cape town za
# sterlibashevo ru
# ribeira grande pt
# yayva ru
# mount gambier au
# ushuaia ar
# ossora ru
# hermanus za
# sheridan us
# ngukurr au
# busselton au
# itaituba br
# sao filipe cv
# pecos us
# punta arenas cl
# victoria sc
# rikitea pf
# ushuaia ar
# rikitea pf
# krivyanskaya ru
# rikitea pf
# rosarito mx
# maumere id
# arraial do cabo br
# albany au
# hermanus za
# azimur ma
# chuy uy
# veraval in
# tasiilaq gl
# aitape pg
# karratha au
# rikitea pf
# ushuaia ar
# cape town za
# san lorenzo ar
# la paz mx
# tambovka ru
# talnakh ru
# qaanaaq gl
# taolanaro mg
# kavieng pg
# kapaa us
# cabo san lucas mx
# kapaa us
# hobart au
# marrakesh ma
# bengkulu id
# rikitea pf
# grindavik is
# kapaa us
# bredasdorp za
# busselton au
# puerto ayora ec
# port alfred za
# hithadhoo mv
# saint george bm
# buluang ph
# hilo us
# mwanza mw
# murray bridge au
# marawi sd
# punta arenas cl
# chokurdakh ru
# atuona pf
# kununurra au
# alta gracia ar
# nikolskoye ru
# mataura pf
# qaanaaq gl
# barrow us
# kaitangata nz
# manosque fr
# ribeira grande pt
# rikitea pf
# new norfolk au
# popondetta pg
# vaini to
# pio xii br
# richards bay za
# nioro ml
# cape town za
# frankfort us
# ushuaia ar
# ilulissat gl
# atuona pf
# hermanus za
# ushuaia ar
# albany au
# tucuman ar
# nara ml
# rikitea pf
# lebork pl
# attawapiskat ca
# mataura pf
# mataura pf
# tiarei pf
# saskylakh ru
# grand river south east mu
# camargo bo
# ushuaia ar
# brewster us
# kaitangata nz
# punta arenas cl
# thompson ca
# gat ly
# mar del plata ar
# janakkala fi
# qaanaaq gl
# puerto ayora ec
# beyneu kz
# punta arenas cl
# mezhova ua
# hilo us
# punta arenas cl
# punta arenas cl
# hobart au
# rikitea pf
# mataura pf
# nome us
# tuatapere nz
# margate za
# samusu ws
# new norfolk au
# mataura pf
# uwayl sd
# labuhan id
# tasiilaq gl
# pevek ru
# henties bay na
# yablonovo ru
# tuktoyaktuk ca
# cape town za
# hermanus za
# ushuaia ar
# hilo us
# zhob pk
# rikitea pf
# carnarvon au
# bredasdorp za
# severobaykalsk ru
# rikitea pf
# otane nz
# punta arenas cl
# qaanaaq gl
# port elizabeth za
# ponta do sol cv
# rikitea pf
# punta arenas cl
# mataura pf
# bethel us
# ketchikan us
# henties bay na
# khatanga ru
# rikitea pf
# buluang ph
# thompson ca
# dingle ie
# baoqing cn
# hermanus za
# nikolskoye ru
# mataura pf
# khatanga ru
# zhigansk ru
# taolanaro mg
# leningradskiy ru
# vardo no
# druzhba ua
# lebu cl
# hermanus za
# ulladulla au
# lakes entrance au
# nome us
# nyagan ru
# siwana in
# morant bay jm
# constantine dz
# bilibino ru
# ribeira grande pt
# luanda ao
# saint anthony ca
# barretos br
# locri it
# airai pw
# atuona pf
# carmen mx
# cape town za
# hamilton bm
# ciudad bolivar ve
# grand river south east mu
# cabo san lucas mx
# sulangan ph
# chapais ca
# bethel us
# tanout ne
# puerto ayora ec
# bairiki ki
# timra se
# new norfolk au
# eureka us
# barrow us
# provideniya ru
# tezu in
# karonga mw
# manacapuru br
# mataura pf
# pangnirtung ca
# vaini to
# grand river south east mu
# albany au
# belushya guba ru
# barra do garcas br
# bolungarvik is
# taolanaro mg
# chistogorskiy ru
# kodiak us
# thompson ca
# pacific grove us
# henties bay na
# provideniya ru
# georgetown sh
# langen de
# vila velha br
# kapaa us
# radyvyliv ua
# kapaa us
# kavieng pg
# norman wells ca
# andenes no
# nguiu au
# russell nz
# yerbogachen ru
# cape town za
# sabzevar ir
# busselton au
# puteyets ru
# asosa et
# vaitupu wf
# punta arenas cl
# bluff nz
# saint-georges gf
# katsuura jp
# torbay ca
# midland us
# saskylakh ru
# grand centre ca
# rikitea pf
# punta arenas cl
# klaksvik fo
# mildura au
# esperance au
# busselton au
# longyearbyen sj
# castro cl
# lanzhou cn
# srednekolymsk ru
# bluff nz
# saint-augustin ca
# tuktoyaktuk ca
# khatanga ru
# hermanus za
# tuatapere nz
# port talbot gb
# san patricio mx
# port pirie au
# punta arenas cl
# tuktoyaktuk ca
# cape town za
# waingapu id
# hilo us
# saint-philippe re
# te anau nz
# mataura pf
# jamestown sh
# saint-philippe re
# taolanaro mg
# saskylakh ru
# saint-philippe re
# allapalli in
# constitucion mx
# esperance au
# waw sd
# port elizabeth za
# hasaki jp
# port alfred za
# hobyo so
# shibarghan af
# dikson ru
# hobart au
# san patricio mx
# kodiak us
# georgetown sh
# rikitea pf
# amderma ru
# manono cd
# butaritari ki
# kavieng pg
# winnemucca us
# castro cl
# rikitea pf
# ostersund se
# hobart au
# port alfred za
# meulaboh id
# port alfred za
# punta arenas cl
# batagay-alyta ru
# colares pt
# hermanus za
# puerto ayora ec
# vaini to
# souillac mu
# alaca tr
# vila franca do campo pt
# silvassa in
# muros es
# barrow us
# sovetskiy ru
# mendahara id
# vaitupu wf
# avarua ck
# gadarwara in
# carnarvon au
# tsihombe mg
# kapaa us
# lompoc us
# puerto ayora ec
# mataura pf
# rikitea pf
# barentsburg sj
# rikitea pf
# georgetown sh
# tsihombe mg
# qandahar af
# hobart au
# codrington ag
# atuona pf
# mar del plata ar
# mataura pf
# busselton au
# kirakira sb
# attawapiskat ca
# saint-philippe re
# puerto escondido mx
# kodiak us
# butaritari ki
# jamestown sh
# dolbeau ca
# rikitea pf
# pitimbu br
# bredasdorp za
# moranbah au
# itarema br
# ushuaia ar
# yellowknife ca
# borogontsy ru
# laguna br
# impfondo cg
# machiques ve
# mar del plata ar
# rikitea pf
# new norfolk au
# geraldton au
# santiago pe
# ushuaia ar
# ushuaia ar
# torbay ca
# punta arenas cl
# sao joao de pirabas br
# salalah om
# hithadhoo mv
# khatanga ru
# ostersund se
# hobart au
# visby se
# kapaa us
# petukhovo ru
# touros br
# poli cm
# ahipara nz
# acarau br
# thompson ca
# hobart au
# attawapiskat ca
# jamestown sh
# savannakhet la
# dakar sn
# new norfolk au
# grand gaube mu
# jamestown sh
# saint-philippe re
# ushuaia ar
# taolanaro mg
# bredasdorp za
# bluff nz
# hobart au
# fort nelson ca
# bengkulu id
# ostrovnoy ru
# vermillion us
# hobart au
# havoysund no
# busselton au
# vaini to
# vaini to
# piranshahr ir
# clyde river ca
# punta arenas cl
# arlit ne
# nikolskoye ru
# komsomolskiy ru
# bredasdorp za
# fredericton ca
# iqaluit ca
# bengkulu id
# atuona pf
# severo-kurilsk ru
# busselton au
# mulege mx
# dikson ru
# pisco pe
# bambous virieux mu
# kulu tr
# ushuaia ar
# hasaki jp
# hilo us
# bonfim br
# belushya guba ru
# devrek tr
# ushuaia ar
# upernavik gl
# kapaa us
# cabo san lucas mx
# dulce nombre de culmi hn
# hermanus za
# port moresby pg
# rikitea pf
# castro cl
# gimli ca
# jadu ly
# kaitangata nz
# kibala ao
# thompson ca
# egvekinot ru
# ondorhaan mn
# tuktoyaktuk ca
# rikitea pf
# illoqqortoormiut gl
# taolanaro mg
# los llanos de aridane es
# westport nz
# mungwi zm
# atuona pf
# port elizabeth za
# busselton au
# kropotkin ru
# college us
# severo-kurilsk ru
# punta arenas cl
# qaqortoq gl
# taolanaro mg
# constitucion mx
# mataura pf
# sur om
# hualmay pe
# busselton au
# bail hongal in
# kargasok ru
# pisco pe
# ushuaia ar
# tuatapere nz
# manyana bw
# pudozh ru
# hualmay pe
# butaritari ki
# fairbanks us
# kamenskoye ru
# castro cl
# hithadhoo mv
# new norfolk au
# vaini to
# saskylakh ru
# qaanaaq gl
# albany au
# albany au
# rikitea pf
# vorukh tj
# east london za
# cape town za
# hobart au
# mataura pf
# meulaboh id
# jamestown sh
# bokspits bw
# ekhabi ru
# mataura pf
# new norfolk au
# shenkursk ru
# hithadhoo mv
# cayenne gf
# cape town za
# hilo us
# constitucion mx
# sao felix do xingu br
# guerrero negro mx
# ushuaia ar
# castro cl
# rikitea pf
# port elizabeth za
# macaboboni ph
# new norfolk au
# busselton au
# vao nc
# albany au
# hilo us
# port-gentil ga
# los alamos us
# la ronge ca
# busselton au
# quelimane mz
# busselton au
# acajutla sv
# port elizabeth za
# taolanaro mg
# ushuaia ar
# pevek ru
# lavrentiya ru
# verkhovazhye ru
# sovetskiy ru
# hobart au
# haflong in
# mithimna gr
# peniche pt
# mariental na
# castro cl
# winnemucca us
# ribeira grande pt
# atuona pf
# kaitangata nz
# taoudenni ml
# kapaa us
# hailar cn
# dikson ru
# avarua ck
# hobart au
# along in
# hohhot cn
# almaznyy ru
# shache cn
# butaritari ki
# albany au
# grand river south east mu
# atuona pf
# touros br
# hobart au
# port elizabeth za
# amderma ru
# upernavik gl
# vila velha br
# albany au
# suntar ru
# bluff nz
# bubaque gw
# tiksi ru
# san cristobal ec
# ushuaia ar
# taolanaro mg
# wajir ke
# kruisfontein za
# rungata ki
# rawson ar
# tasiilaq gl
# hithadhoo mv
# terrace ca
# luanda ao
# bambous virieux mu
# jamestown sh
# wewak pg
# nome us
# constitucion mx
# avera pf
# faanui pf
# yellowknife ca
# haines junction ca
# constitucion mx
# avarua ck
# albany au
# meulaboh id
# rikitea pf
# georgetown sh
# junction city us
# hermanus za
# mahesana in
# avarua ck
# arraial do cabo br
# iqaluit ca
# banyo cm
# castro cl
# pervomayskoye ru
# port alfred za
# punta arenas cl
# albany au
# burgeo ca
# yerbogachen ru
# hithadhoo mv
# banda aceh id
# taolanaro mg
# tanshui tw
# astoria us
# qaanaaq gl
# rikitea pf
# hobart au
# norman wells ca
# maceio br
# katsuura jp
# ushuaia ar
# tiksi ru
# arraial do cabo br
# port alfred za
# puerto ayora ec
# kahului us
# atuona pf
# ardistan ir
# bluff nz
# tahe cn
# fairbanks us
# nizhneyansk ru
# cabra ph
# coahuayana mx
# ushuaia ar
# constitucion mx
# thompson ca
# salalah om
# atuona pf
# albany au
# cape town za
# bara sd
# bolungarvik is
# santa rosa bo
# atambua id
# tauranga nz
# vostok ru
# port alfred za
# bengkulu id
# punta arenas cl
# homer us
# port alfred za
# sergeyevka kz
# biltine td
# vaitupu wf
# iqaluit ca
# ushuaia ar
# yellowknife ca
# rio grande br
# hilo us
# shimoda jp
# barentsburg sj
# codrington ag
# ranst be
# sentyabrskiy ru
# kaitangata nz
# illoqqortoormiut gl
# vaini to
# albany au
# nuevo casas grandes mx
# victoria sc
# chokurdakh ru
# tuscaloosa us
# atuona pf
# thompson ca
# rikitea pf
# rikitea pf
# dhidhdhoo mv
# ushuaia ar
# hilo us
# hualmay pe
# kapaa us
# hobart au

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 602

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7fa369148c2f090d340e76858b088376

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7fa369148c2f090d340e76858b088376&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.06,"lat":42.36},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}],"base":"stations","main":{"temp":78.6,"feels_like":78.1,"temp_min":73,"temp_max":82.99,"pressure":1008,"humidity":60},"visibility":10000,"wind":{"speed":9.17,"deg":100},"clouds":{"all":40},"dt":1598651229,"sys":{"type":1,"id":3486,"country":"US","sunrise":1598609154,"sunset":1598657111},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 78.6,
#   'feels_like': 78.1,
#   'temp_min': 73,
#   'temp_max': 82.99,
#   'pressure': 1008,
#   'humidity': 60},
#  'visibility': 10000,
#  'wind': {'speed': 9.17, 'deg': 100},
#  'clouds': {'all': 40},
#  'dt': 1598651229,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1598609154,
#   'sunset': 1598657111},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7fa369148c2f090d340e76858b088376&q=Bston

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 78.6,
#   'feels_like': 78.1,
#   'temp_min': 73,
#   'temp_max': 82.99,
#   'pressure': 1008,
#   'humidity': 60},
#  'visibility': 10000,
#  'wind': {'speed': 9.17, 'deg': 100},
#  'clouds': {'all': 40},
#  'dt': 1598651229,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1598609154,
#   'sunset': 1598657111},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']
# Out:
# {'type': 1,
#  'id': 3486,
#  'country': 'US',
#  'sunrise': 1598609154,
#  'sunset': 1598657111}

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.36 -71.06 82.99 60 40 9.17

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2020-08-28 21:47:09'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city.
    city_url = url + '&q=' + city.replace(' ','+')
    
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    # Add 1 to the record count
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({'City': city.title(),
                         'Lat': city_lat,
                         'Lng': city_lng,
                         'Max Temp': city_max_temp,
                         'Humidity': city_humidity,
                         'Cloudiness': city_clouds,
                         'Wind Speed': city_wind,
                         'Country': city_country,
                         'Date': city_date})
        
# If an error is experienced, skip the city.
    except:
        print('City not found. Skipping...')
        pass

# Indicate that Dat Loading is complete.
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | finschhafen
# Processing Record 2 of Set 1 | kulhudhuffushi
# Processing Record 3 of Set 1 | tunceli
# Processing Record 4 of Set 1 | torbay
# Processing Record 5 of Set 1 | tandalti
# Processing Record 6 of Set 1 | wawa
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | gazojak
# Processing Record 10 of Set 1 | namwala
# Processing Record 11 of Set 1 | auki
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | caravelas
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | severo-kurilsk
# Processing Record 16 of Set 1 | saint george
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | airai
# Processing Record 19 of Set 1 | luderitz
# Processing Record 20 of Set 1 | partenit
# Processing Record 21 of Set 1 | cidreira
# Processing Record 22 of Set 1 | clarksburg
# Processing Record 23 of Set 1 | souillac
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 1 | santa marta de tormes
# Processing Record 28 of Set 1 | hambantota
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | saryagash
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | nome
# Processing Record 33 of Set 1 | rawson
# Processing Record 34 of Set 1 | belo oriente
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | cabo san lucas
# Processing Record 38 of Set 1 | banda aceh
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | tiksi
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | conakry
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | olot
# Processing Record 46 of Set 1 | pundaguitan
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | port shepstone
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | narsaq
# Processing Record 1 of Set 2 | ust-maya
# Processing Record 2 of Set 2 | saint-philippe
# Processing Record 3 of Set 2 | talcahuano
# Processing Record 4 of Set 2 | lucea
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | half moon bay
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | fortuna
# Processing Record 10 of Set 2 | san quintin
# Processing Record 11 of Set 2 | hermanus
# Processing Record 12 of Set 2 | worland
# Processing Record 13 of Set 2 | ierapetra
# Processing Record 14 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 2 | logan lake
# Processing Record 16 of Set 2 | maragheh
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | am timan
# Processing Record 19 of Set 2 | kodar
# Processing Record 20 of Set 2 | sept-iles
# Processing Record 21 of Set 2 | ixtapa
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | cockburn town
# Processing Record 24 of Set 2 | sao joao da barra
# Processing Record 25 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 2 | urambo
# Processing Record 28 of Set 2 | pangnirtung
# Processing Record 29 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 2 | lompoc
# Processing Record 31 of Set 2 | bulungu
# Processing Record 32 of Set 2 | nanakuli
# Processing Record 33 of Set 2 | noshiro
# Processing Record 34 of Set 2 | bredasdorp
# Processing Record 35 of Set 2 | vila velha
# Processing Record 36 of Set 2 | maragogi
# Processing Record 37 of Set 2 | shiggaon
# Processing Record 38 of Set 2 | dehui
# Processing Record 39 of Set 2 | el alto
# Processing Record 40 of Set 2 | roald
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | allende
# Processing Record 43 of Set 2 | nenjiang
# Processing Record 44 of Set 2 | zvishavane
# Processing Record 45 of Set 2 | granby
# Processing Record 46 of Set 2 | norman wells
# Processing Record 47 of Set 2 | namibe
# Processing Record 48 of Set 2 | la ronge
# Processing Record 49 of Set 2 | saskylakh
# Processing Record 50 of Set 2 | georgetown
# Processing Record 1 of Set 3 | mar del plata
# Processing Record 2 of Set 3 | guayaramerin
# Processing Record 3 of Set 3 | eureka
# Processing Record 4 of Set 3 | barrow
# Processing Record 5 of Set 3 | port alfred
# Processing Record 6 of Set 3 | richards bay
# Processing Record 7 of Set 3 | ust-nera
# Processing Record 8 of Set 3 | dingle
# Processing Record 9 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 3 | karpogory
# Processing Record 11 of Set 3 | ostrovnoy
# Processing Record 12 of Set 3 | salalah
# Processing Record 13 of Set 3 | mahebourg
# Processing Record 14 of Set 3 | fairbanks
# Processing Record 15 of Set 3 | puerto ayacucho
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | xining
# Processing Record 18 of Set 3 | nanortalik
# Processing Record 19 of Set 3 | avera
# Processing Record 20 of Set 3 | labuan
# Processing Record 21 of Set 3 | trinidad
# Processing Record 22 of Set 3 | dingli
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | vardo
# Processing Record 25 of Set 3 | santa maria
# Processing Record 26 of Set 3 | laerdalsoyri
# Processing Record 27 of Set 3 | semey
# Processing Record 28 of Set 3 | adrar
# Processing Record 29 of Set 3 | taoudenni
# Processing Record 30 of Set 3 | qaqortoq
# Processing Record 31 of Set 3 | alexandria
# Processing Record 32 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 3 | bambous virieux
# Processing Record 34 of Set 3 | klaksvik
# Processing Record 35 of Set 3 | sao filipe
# Processing Record 36 of Set 3 | poum
# Processing Record 37 of Set 3 | pamekasan
# Processing Record 38 of Set 3 | port-gentil
# Processing Record 39 of Set 3 | san buenaventura
# Processing Record 40 of Set 3 | taicheng
# Processing Record 41 of Set 3 | la ligua
# Processing Record 42 of Set 3 | dunedin
# Processing Record 43 of Set 3 | san patricio
# Processing Record 44 of Set 3 | atuona
# Processing Record 45 of Set 3 | alice springs
# Processing Record 46 of Set 3 | mwinilunga
# Processing Record 47 of Set 3 | holiday
# Processing Record 48 of Set 3 | asbe teferi
# Processing Record 49 of Set 3 | balikpapan
# Processing Record 50 of Set 3 | atagay
# Processing Record 1 of Set 4 | sao jose da coroa grande
# Processing Record 2 of Set 4 | canico
# Processing Record 3 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 4 | kapaa
# Processing Record 5 of Set 4 | tuatapere
# Processing Record 6 of Set 4 | busselton
# Processing Record 7 of Set 4 | kaitangata
# Processing Record 8 of Set 4 | hithadhoo
# Processing Record 9 of Set 4 | les cayes
# Processing Record 10 of Set 4 | saposoa
# Processing Record 11 of Set 4 | khatanga
# Processing Record 12 of Set 4 | svetlaya
# Processing Record 13 of Set 4 | nuevo progreso
# Processing Record 14 of Set 4 | naqadeh
# Processing Record 15 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 4 | santiago del estero
# Processing Record 17 of Set 4 | port hedland
# Processing Record 18 of Set 4 | bowen
# Processing Record 19 of Set 4 | castro
# Processing Record 20 of Set 4 | anchorage
# Processing Record 21 of Set 4 | altay
# Processing Record 22 of Set 4 | horta
# Processing Record 23 of Set 4 | hay river
# Processing Record 24 of Set 4 | vallenar
# Processing Record 25 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 4 | anloga
# Processing Record 27 of Set 4 | aksha
# Processing Record 28 of Set 4 | kaeo
# Processing Record 29 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 4 | keuruu
# Processing Record 31 of Set 4 | raichur
# Processing Record 32 of Set 4 | mulege
# Processing Record 33 of Set 4 | faanui
# Processing Record 34 of Set 4 | shushtar
# Processing Record 35 of Set 4 | bethel
# Processing Record 36 of Set 4 | clyde river
# Processing Record 37 of Set 4 | codrington
# Processing Record 38 of Set 4 | usinsk
# Processing Record 39 of Set 4 | redmond
# Processing Record 40 of Set 4 | chepen
# Processing Record 41 of Set 4 | kodiak
# Processing Record 42 of Set 4 | kununurra
# Processing Record 43 of Set 4 | kloulklubed
# Processing Record 44 of Set 4 | oussouye
# Processing Record 45 of Set 4 | laizhou
# Processing Record 46 of Set 4 | hasaki
# Processing Record 47 of Set 4 | marck
# Processing Record 48 of Set 4 | puerto escondido
# Processing Record 49 of Set 4 | porto novo
# Processing Record 50 of Set 4 | coquimbo
# Processing Record 1 of Set 5 | san cristobal
# Processing Record 2 of Set 5 | buzmeyin
# Processing Record 3 of Set 5 | susangerd
# Processing Record 4 of Set 5 | jiaxing
# Processing Record 5 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 5 | grand gaube
# Processing Record 7 of Set 5 | geraldton
# Processing Record 8 of Set 5 | vega de alatorre
# Processing Record 9 of Set 5 | erdenet
# Processing Record 10 of Set 5 | nikolskoye
# Processing Record 11 of Set 5 | matagami
# Processing Record 12 of Set 5 | beringovskiy
# Processing Record 13 of Set 5 | lata
# Processing Record 14 of Set 5 | vysokogornyy
# Processing Record 15 of Set 5 | bengkulu
# Processing Record 16 of Set 5 | maple creek
# Processing Record 17 of Set 5 | krasnoselkup
# Processing Record 18 of Set 5 | jining
# Processing Record 19 of Set 5 | voznesenye
# Processing Record 20 of Set 5 | sola
# Processing Record 21 of Set 5 | jalu
# Processing Record 22 of Set 5 | xuddur
# Processing Record 23 of Set 5 | jamestown
# Processing Record 24 of Set 5 | mehamn
# Processing Record 25 of Set 5 | nsanje
# Processing Record 26 of Set 5 | mezen
# Processing Record 27 of Set 5 | isperih
# Processing Record 28 of Set 5 | lappeenranta
# Processing Record 29 of Set 5 | ballina
# Processing Record 30 of Set 5 | whitecourt
# Processing Record 31 of Set 5 | sussex
# Processing Record 32 of Set 5 | reynosa
# Processing Record 33 of Set 5 | chokurdakh
# Processing Record 34 of Set 5 | madawaska
# Processing Record 35 of Set 5 | carnarvon
# Processing Record 36 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 5 | maniitsoq
# Processing Record 38 of Set 5 | kainantu
# Processing Record 39 of Set 5 | bathsheba
# Processing Record 40 of Set 5 | vao
# Processing Record 41 of Set 5 | chipinge
# Processing Record 42 of Set 5 | margate
# Processing Record 43 of Set 5 | palkino
# Processing Record 44 of Set 5 | bure
# Processing Record 45 of Set 5 | mizdah
# Processing Record 46 of Set 5 | portland
# Processing Record 47 of Set 5 | burica
# City not found. Skipping...
# Processing Record 48 of Set 5 | ahipara
# Processing Record 49 of Set 5 | kahului
# Processing Record 50 of Set 5 | acarau
# Processing Record 1 of Set 6 | provideniya
# Processing Record 2 of Set 6 | kresek
# Processing Record 3 of Set 6 | morro bay
# Processing Record 4 of Set 6 | ribeira brava
# Processing Record 5 of Set 6 | praia
# Processing Record 6 of Set 6 | jelenia gora
# Processing Record 7 of Set 6 | chapais
# Processing Record 8 of Set 6 | marsh harbour
# Processing Record 9 of Set 6 | barra do garcas
# Processing Record 10 of Set 6 | san carlos de bariloche
# Processing Record 11 of Set 6 | koluszki
# Processing Record 12 of Set 6 | sinop
# Processing Record 13 of Set 6 | westport
# Processing Record 14 of Set 6 | busko-zdroj
# Processing Record 15 of Set 6 | lorengau
# Processing Record 16 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 6 | bilma
# Processing Record 18 of Set 6 | agua dulce
# Processing Record 19 of Set 6 | ulles
# Processing Record 20 of Set 6 | leh
# Processing Record 21 of Set 6 | alofi
# Processing Record 22 of Set 6 | abnub
# Processing Record 23 of Set 6 | cananeia
# Processing Record 24 of Set 6 | santa rita
# Processing Record 25 of Set 6 | constitucion
# Processing Record 26 of Set 6 | thompson
# Processing Record 27 of Set 6 | chikhli
# Processing Record 28 of Set 6 | upernavik
# Processing Record 29 of Set 6 | walvis bay
# Processing Record 30 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 6 | hargeysa
# Processing Record 32 of Set 6 | nyrob
# Processing Record 33 of Set 6 | sitka
# Processing Record 34 of Set 6 | toamasina
# Processing Record 35 of Set 6 | paamiut
# Processing Record 36 of Set 6 | raga
# Processing Record 37 of Set 6 | jibuti
# Processing Record 38 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 39 of Set 6 | talnakh
# Processing Record 40 of Set 6 | grindavik
# Processing Record 41 of Set 6 | viedma
# Processing Record 42 of Set 6 | tasco
# Processing Record 43 of Set 6 | quang ngai
# Processing Record 44 of Set 6 | san carlos
# Processing Record 45 of Set 6 | lebu
# Processing Record 46 of Set 6 | mae sai
# Processing Record 47 of Set 6 | innisfail
# Processing Record 48 of Set 6 | goderich
# Processing Record 49 of Set 6 | faya
# Processing Record 50 of Set 6 | howard springs
# Processing Record 1 of Set 7 | deputatskiy
# Processing Record 2 of Set 7 | ust-omchug
# Processing Record 3 of Set 7 | garissa
# Processing Record 4 of Set 7 | lagoa santa
# Processing Record 5 of Set 7 | vohibinany
# Processing Record 6 of Set 7 | ponta do sol
# Processing Record 7 of Set 7 | morros
# Processing Record 8 of Set 7 | mount gambier
# Processing Record 9 of Set 7 | lavrentiya
# Processing Record 10 of Set 7 | huanren
# Processing Record 11 of Set 7 | myitkyina
# Processing Record 12 of Set 7 | orbetello
# Processing Record 13 of Set 7 | broome
# Processing Record 14 of Set 7 | kenai
# Processing Record 15 of Set 7 | omboue
# Processing Record 16 of Set 7 | muros
# Processing Record 17 of Set 7 | zambezi
# Processing Record 18 of Set 7 | znamenskoye
# Processing Record 19 of Set 7 | tabou
# Processing Record 20 of Set 7 | sarangani
# Processing Record 21 of Set 7 | dwarka
# Processing Record 22 of Set 7 | erzin
# Processing Record 23 of Set 7 | fort-shevchenko
# Processing Record 24 of Set 7 | riberalta
# Processing Record 25 of Set 7 | san jose
# Processing Record 26 of Set 7 | barlinek
# Processing Record 27 of Set 7 | isiro
# Processing Record 28 of Set 7 | mildura
# Processing Record 29 of Set 7 | redlands
# Processing Record 30 of Set 7 | padang
# Processing Record 31 of Set 7 | verkh-suetka
# Processing Record 32 of Set 7 | kropotkin
# Processing Record 33 of Set 7 | port macquarie
# Processing Record 34 of Set 7 | conway
# Processing Record 35 of Set 7 | coahuayana
# Processing Record 36 of Set 7 | nouadhibou
# Processing Record 37 of Set 7 | berdigestyakh
# Processing Record 38 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 7 | shimoda
# Processing Record 40 of Set 7 | sainte-maxime
# Processing Record 41 of Set 7 | solwezi
# Processing Record 42 of Set 7 | laguna
# Processing Record 43 of Set 7 | vestmannaeyjar
# Processing Record 44 of Set 7 | dekar
# Processing Record 45 of Set 7 | sangar
# Processing Record 46 of Set 7 | lieksa
# Processing Record 47 of Set 7 | nyurba
# Processing Record 48 of Set 7 | havoysund
# Processing Record 49 of Set 7 | susehri
# Processing Record 50 of Set 7 | taebla
# Processing Record 1 of Set 8 | sao gabriel da cachoeira
# Processing Record 2 of Set 8 | antofagasta
# Processing Record 3 of Set 8 | katsuura
# Processing Record 4 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 8 | yalutorovsk
# Processing Record 6 of Set 8 | maputo
# Processing Record 7 of Set 8 | batagay-alyta
# Processing Record 8 of Set 8 | bubaque
# Processing Record 9 of Set 8 | tambura
# Processing Record 10 of Set 8 | akhtanizovskaya
# Processing Record 11 of Set 8 | lagoa
# Processing Record 12 of Set 8 | touros
# Processing Record 13 of Set 8 | hervey bay
# Processing Record 14 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 8 | aksarka
# Processing Record 16 of Set 8 | guerrero negro
# Processing Record 17 of Set 8 | eyl
# Processing Record 18 of Set 8 | gat
# Processing Record 19 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 8 | springbok
# Processing Record 21 of Set 8 | lagunas
# Processing Record 22 of Set 8 | iquique
# Processing Record 23 of Set 8 | flin flon
# Processing Record 24 of Set 8 | zhuhai
# Processing Record 25 of Set 8 | saint-pierre
# Processing Record 26 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 8 | bonthe
# Processing Record 28 of Set 8 | verkhoyansk
# Processing Record 29 of Set 8 | gornji milanovac
# Processing Record 30 of Set 8 | cherskiy
# Processing Record 31 of Set 8 | vondrozo
# Processing Record 32 of Set 8 | mana
# Processing Record 33 of Set 8 | schroeder
# Processing Record 34 of Set 8 | vanavara
# Processing Record 35 of Set 8 | phan thiet
# Processing Record 36 of Set 8 | esperance
# Processing Record 37 of Set 8 | tyret pervaya
# Processing Record 38 of Set 8 | leningradskiy
# Processing Record 39 of Set 8 | sechura
# Processing Record 40 of Set 8 | akdepe
# Processing Record 41 of Set 8 | guiyang
# Processing Record 42 of Set 8 | umm ruwabah
# City not found. Skipping...
# Processing Record 43 of Set 8 | rio grande
# Processing Record 44 of Set 8 | hamilton
# Processing Record 45 of Set 8 | nova olimpia
# Processing Record 46 of Set 8 | astana
# Processing Record 47 of Set 8 | monster
# Processing Record 48 of Set 8 | ambunti
# Processing Record 49 of Set 8 | jodoigne
# Processing Record 50 of Set 8 | sterlibashevo
# Processing Record 1 of Set 9 | yayva
# Processing Record 2 of Set 9 | ossora
# Processing Record 3 of Set 9 | sheridan
# Processing Record 4 of Set 9 | itaituba
# Processing Record 5 of Set 9 | pecos
# Processing Record 6 of Set 9 | victoria
# Processing Record 7 of Set 9 | krivyanskaya
# Processing Record 8 of Set 9 | rosarito
# Processing Record 9 of Set 9 | maumere
# Processing Record 10 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 11 of Set 9 | chuy
# Processing Record 12 of Set 9 | veraval
# Processing Record 13 of Set 9 | aitape
# Processing Record 14 of Set 9 | karratha
# Processing Record 15 of Set 9 | san lorenzo
# Processing Record 16 of Set 9 | la paz
# Processing Record 17 of Set 9 | tambovka
# Processing Record 18 of Set 9 | kavieng
# Processing Record 19 of Set 9 | marrakesh
# Processing Record 20 of Set 9 | buluang
# Processing Record 21 of Set 9 | mwanza
# Processing Record 22 of Set 9 | murray bridge
# Processing Record 23 of Set 9 | marawi
# Processing Record 24 of Set 9 | alta gracia
# Processing Record 25 of Set 9 | manosque
# Processing Record 26 of Set 9 | popondetta
# Processing Record 27 of Set 9 | pio xii
# Processing Record 28 of Set 9 | nioro
# Processing Record 29 of Set 9 | frankfort
# Processing Record 30 of Set 9 | ilulissat
# Processing Record 31 of Set 9 | tucuman
# Processing Record 32 of Set 9 | nara
# Processing Record 33 of Set 9 | lebork
# Processing Record 34 of Set 9 | tiarei
# Processing Record 35 of Set 9 | camargo
# Processing Record 36 of Set 9 | brewster
# Processing Record 37 of Set 9 | janakkala
# Processing Record 38 of Set 9 | beyneu
# Processing Record 39 of Set 9 | mezhova
# Processing Record 40 of Set 9 | uwayl
# City not found. Skipping...
# Processing Record 41 of Set 9 | labuhan
# Processing Record 42 of Set 9 | pevek
# Processing Record 43 of Set 9 | henties bay
# Processing Record 44 of Set 9 | yablonovo
# Processing Record 45 of Set 9 | zhob
# Processing Record 46 of Set 9 | severobaykalsk
# Processing Record 47 of Set 9 | otane
# Processing Record 48 of Set 9 | ketchikan
# Processing Record 49 of Set 9 | baoqing
# Processing Record 50 of Set 9 | zhigansk
# Processing Record 1 of Set 10 | druzhba
# Processing Record 2 of Set 10 | ulladulla
# Processing Record 3 of Set 10 | lakes entrance
# Processing Record 4 of Set 10 | nyagan
# Processing Record 5 of Set 10 | siwana
# Processing Record 6 of Set 10 | morant bay
# Processing Record 7 of Set 10 | constantine
# Processing Record 8 of Set 10 | bilibino
# Processing Record 9 of Set 10 | luanda
# Processing Record 10 of Set 10 | saint anthony
# Processing Record 11 of Set 10 | barretos
# Processing Record 12 of Set 10 | locri
# Processing Record 13 of Set 10 | carmen
# Processing Record 14 of Set 10 | ciudad bolivar
# Processing Record 15 of Set 10 | sulangan
# Processing Record 16 of Set 10 | tanout
# Processing Record 17 of Set 10 | bairiki
# Processing Record 18 of Set 10 | timra
# Processing Record 19 of Set 10 | tezu
# Processing Record 20 of Set 10 | karonga
# Processing Record 21 of Set 10 | manacapuru
# Processing Record 22 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 10 | chistogorskiy
# Processing Record 24 of Set 10 | pacific grove
# Processing Record 25 of Set 10 | langen
# Processing Record 26 of Set 10 | radyvyliv
# Processing Record 27 of Set 10 | andenes
# Processing Record 28 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 10 | russell
# Processing Record 30 of Set 10 | yerbogachen
# Processing Record 31 of Set 10 | sabzevar
# Processing Record 32 of Set 10 | puteyets
# Processing Record 33 of Set 10 | asosa
# Processing Record 34 of Set 10 | saint-georges
# Processing Record 35 of Set 10 | midland
# Processing Record 36 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 37 of Set 10 | longyearbyen
# Processing Record 38 of Set 10 | lanzhou
# Processing Record 39 of Set 10 | srednekolymsk
# Processing Record 40 of Set 10 | saint-augustin
# Processing Record 41 of Set 10 | port talbot
# Processing Record 42 of Set 10 | port pirie
# Processing Record 43 of Set 10 | waingapu
# Processing Record 44 of Set 10 | te anau
# Processing Record 45 of Set 10 | allapalli
# Processing Record 46 of Set 10 | waw
# Processing Record 47 of Set 10 | hobyo
# Processing Record 48 of Set 10 | shibarghan
# City not found. Skipping...
# Processing Record 49 of Set 10 | manono
# Processing Record 50 of Set 10 | winnemucca
# Processing Record 1 of Set 11 | ostersund
# Processing Record 2 of Set 11 | meulaboh
# Processing Record 3 of Set 11 | colares
# Processing Record 4 of Set 11 | alaca
# Processing Record 5 of Set 11 | vila franca do campo
# Processing Record 6 of Set 11 | silvassa
# Processing Record 7 of Set 11 | sovetskiy
# Processing Record 8 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 9 of Set 11 | gadarwara
# Processing Record 10 of Set 11 | qandahar
# City not found. Skipping...
# Processing Record 11 of Set 11 | kirakira
# Processing Record 12 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 13 of Set 11 | pitimbu
# Processing Record 14 of Set 11 | moranbah
# Processing Record 15 of Set 11 | itarema
# Processing Record 16 of Set 11 | borogontsy
# Processing Record 17 of Set 11 | impfondo
# Processing Record 18 of Set 11 | machiques
# Processing Record 19 of Set 11 | santiago
# Processing Record 20 of Set 11 | sao joao de pirabas
# Processing Record 21 of Set 11 | visby
# Processing Record 22 of Set 11 | petukhovo
# Processing Record 23 of Set 11 | poli
# Processing Record 24 of Set 11 | savannakhet
# Processing Record 25 of Set 11 | dakar
# Processing Record 26 of Set 11 | fort nelson
# Processing Record 27 of Set 11 | vermillion
# Processing Record 28 of Set 11 | piranshahr
# Processing Record 29 of Set 11 | arlit
# Processing Record 30 of Set 11 | komsomolskiy
# Processing Record 31 of Set 11 | fredericton
# Processing Record 32 of Set 11 | iqaluit
# Processing Record 33 of Set 11 | pisco
# Processing Record 34 of Set 11 | kulu
# Processing Record 35 of Set 11 | bonfim
# Processing Record 36 of Set 11 | devrek
# Processing Record 37 of Set 11 | dulce nombre de culmi
# Processing Record 38 of Set 11 | port moresby
# Processing Record 39 of Set 11 | gimli
# Processing Record 40 of Set 11 | jadu
# Processing Record 41 of Set 11 | kibala
# Processing Record 42 of Set 11 | egvekinot
# Processing Record 43 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 44 of Set 11 | los llanos de aridane
# Processing Record 45 of Set 11 | mungwi
# Processing Record 46 of Set 11 | college
# Processing Record 47 of Set 11 | sur
# Processing Record 48 of Set 11 | hualmay
# Processing Record 49 of Set 11 | bail hongal
# Processing Record 50 of Set 11 | kargasok
# Processing Record 1 of Set 12 | manyana
# Processing Record 2 of Set 12 | pudozh
# Processing Record 3 of Set 12 | vorukh
# Processing Record 4 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 5 of Set 12 | ekhabi
# Processing Record 6 of Set 12 | shenkursk
# Processing Record 7 of Set 12 | cayenne
# Processing Record 8 of Set 12 | sao felix do xingu
# Processing Record 9 of Set 12 | macaboboni
# City not found. Skipping...
# Processing Record 10 of Set 12 | los alamos
# Processing Record 11 of Set 12 | quelimane
# Processing Record 12 of Set 12 | acajutla
# Processing Record 13 of Set 12 | verkhovazhye
# Processing Record 14 of Set 12 | haflong
# Processing Record 15 of Set 12 | mithimna
# City not found. Skipping...
# Processing Record 16 of Set 12 | peniche
# Processing Record 17 of Set 12 | mariental
# Processing Record 18 of Set 12 | hailar
# Processing Record 19 of Set 12 | along
# Processing Record 20 of Set 12 | hohhot
# Processing Record 21 of Set 12 | almaznyy
# Processing Record 22 of Set 12 | shache
# Processing Record 23 of Set 12 | suntar
# Processing Record 24 of Set 12 | wajir
# Processing Record 25 of Set 12 | kruisfontein
# Processing Record 26 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 12 | terrace
# Processing Record 28 of Set 12 | wewak
# Processing Record 29 of Set 12 | haines junction
# Processing Record 30 of Set 12 | junction city
# Processing Record 31 of Set 12 | mahesana
# Processing Record 32 of Set 12 | banyo
# Processing Record 33 of Set 12 | pervomayskoye
# Processing Record 34 of Set 12 | burgeo
# Processing Record 35 of Set 12 | tanshui
# City not found. Skipping...
# Processing Record 36 of Set 12 | astoria
# Processing Record 37 of Set 12 | maceio
# Processing Record 38 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 39 of Set 12 | tahe
# Processing Record 40 of Set 12 | cabra
# Processing Record 41 of Set 12 | bara
# Processing Record 42 of Set 12 | santa rosa
# Processing Record 43 of Set 12 | atambua
# Processing Record 44 of Set 12 | tauranga
# Processing Record 45 of Set 12 | vostok
# Processing Record 46 of Set 12 | homer
# Processing Record 47 of Set 12 | sergeyevka
# Processing Record 48 of Set 12 | biltine
# Processing Record 49 of Set 12 | ranst
# Processing Record 50 of Set 12 | nuevo casas grandes
# Processing Record 1 of Set 13 | tuscaloosa
# Processing Record 2 of Set 13 | dhidhdhoo
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Finschhafen  -6.60  147.87     78.96        83         100        7.36
# 1  Kulhudhuffushi   6.62   73.07     82.36        74           7       11.34
# 2         Tunceli  39.11   39.55     80.60        21           0        1.12
# 3          Torbay  47.67  -52.73     62.60        51          75       16.11
# 4        Tandalti  13.02   31.87     82.45        63         100        3.15
# 5            Wawa   9.90    4.42     73.29        92          64        5.97
# 6           Bluff -46.60  168.33     45.00        72          88       11.01
# 7      Butaritari   3.07  172.79     82.27        74         100       15.21
# 8         Gazojak  41.19   61.40     73.15        26           0       10.78
# 9         Namwala -15.75   26.44     66.52        30           1        4.16
#
#   Country                 Date
# 0      PG  2020-08-28 21:54:41
# 1      MV  2020-08-28 21:54:41
# 2      TR  2020-08-28 21:54:42
# 3      CA  2020-08-28 21:49:12
# 4      SD  2020-08-28 21:54:42
# 5      NG  2020-08-28 21:54:42
# 6      NZ  2020-08-28 21:49:17
# 7      KI  2020-08-28 21:49:22
# 8      TM  2020-08-28 21:54:42
# 9      ZM  2020-08-28 21:50:53

# %%
# Reorder the columns
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0     Finschhafen      PG  2020-08-28 21:54:41  -6.60  147.87     78.96
# 1  Kulhudhuffushi      MV  2020-08-28 21:54:41   6.62   73.07     82.36
# 2         Tunceli      TR  2020-08-28 21:54:42  39.11   39.55     80.60
# 3          Torbay      CA  2020-08-28 21:49:12  47.67  -52.73     62.60
# 4        Tandalti      SD  2020-08-28 21:54:42  13.02   31.87     82.45
# 5            Wawa      NG  2020-08-28 21:54:42   9.90    4.42     73.29
# 6           Bluff      NZ  2020-08-28 21:49:17 -46.60  168.33     45.00
# 7      Butaritari      KI  2020-08-28 21:49:22   3.07  172.79     82.27
# 8         Gazojak      TM  2020-08-28 21:54:42  41.19   61.40     73.15
# 9         Namwala      ZM  2020-08-28 21:50:53 -15.75   26.44     66.52
#
#    Humidity  Cloudiness  Wind Speed
# 0        83         100        7.36
# 1        74           7       11.34
# 2        21           0        1.12
# 3        51          75       16.11
# 4        63         100        3.15
# 5        92          64        5.97
# 6        72          88       11.01
# 7        74         100       15.21
# 8        26           0       10.78
# 9        30           1        4.16

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.strftime("%x")
today
# Out:
# '08/28/20'

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linear regression from SciPy stats module
from scipy.stats import linregress

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City               Ribeira Grande
# Country                        PT
# Date          2020-08-28 21:49:25
# Lat                         38.52
# Lng                         -28.7
# Max Temp                    74.66
# Humidity                       92
# Cloudiness                     13
# Wind Speed                  11.54
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 556     True
# 557     True
# 558     True
# 559     True
# 560     True
# Name: Lat, Length: 561, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Out:
#                     City Country                 Date    Lat     Lng  \
# 1         Kulhudhuffushi      MV  2020-08-28 21:54:41   6.62   73.07
# 2                Tunceli      TR  2020-08-28 21:54:42  39.11   39.55
# 3                 Torbay      CA  2020-08-28 21:49:12  47.67  -52.73
# 4               Tandalti      SD  2020-08-28 21:54:42  13.02   31.87
# 5                   Wawa      NG  2020-08-28 21:54:42   9.90    4.42
# ..                   ...     ...                  ...    ...     ...
# 556              Biltine      TD  2020-08-28 21:55:41  14.53   20.92
# 557                Ranst      BE  2020-08-28 21:55:41  51.19    4.57
# 558  Nuevo Casas Grandes      MX  2020-08-28 21:55:42  30.42 -107.92
# 559           Tuscaloosa      US  2020-08-28 21:52:03  33.21  -87.57
# 560            Dhidhdhoo      MV  2020-08-28 21:55:42   6.88   73.10
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 1       82.36        74           7       11.34
# 2       80.60        21           0        1.12
# 3       62.60        51          75       16.11
# 4       82.45        63         100        3.15
# 5       73.29        92          64        5.97
# ..        ...       ...         ...         ...
# 556     81.41        67          78        5.12
# 557     61.00        82           0        5.82
# 558     97.00        15          21       10.00
# 559     84.20        79          40       17.22
# 560     82.42        74          10       11.27
#
# [386 rows x 9 columns]

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Humidity', '% Humidity',(-50,15))

# %%
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

# Call the function.
plot_linear_regression(x_values, y_values,
                       "Linear Regression on the Northern Hemisphere \n" 
                       "for % Cloudiness", '% Cloudiness', (10,55))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-50,35))

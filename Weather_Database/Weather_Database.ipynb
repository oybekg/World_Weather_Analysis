# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to the cities list.
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 783

# %%
import requests 

from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

# Print the beginning of the logging.
print('Beginning Data Retrieval          ')
print('----------------------------------')

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1

    # Run the API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_descrip = city_weather['weather'][0]['description']
        city_country = city_weather['sys']['country']
        # Append the city information into a city_data list.
        city_data.append({'City': city.title(),
                         'Country': city_country,
                         'Lat': city_lat,
                         'Lng': city_lng,
                         'Max Temp': city_max_temp,
                         'Humidity': city_humidity,
                         'Cloudiness': city_clouds,
                         'Wind Speed': city_wind,
                         'Current Description': city_descrip})
    
    #If error skip the city.
    except:
        print('City not found. Skipping...')
        pass
    
# Indicate that the data loading is complete.
print('----------------------------------')
print('Data Retrieval Complete           ')
print('----------------------------------')
# Out:
# Beginning Data Retrieval
# ----------------------------------
# Processing Record 1 of Set 1 | annau
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 1 | kuching
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | stutterheim
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | high level
# Processing Record 10 of Set 1 | ostrovnoy
# Processing Record 11 of Set 1 | tiarei
# Processing Record 12 of Set 1 | ketchikan
# Processing Record 13 of Set 1 | santiago del estero
# Processing Record 14 of Set 1 | teknaf
# Processing Record 15 of Set 1 | haines junction
# Processing Record 16 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 1 | charters towers
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | ilulissat
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | gotsu
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | octeville
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | san patricio
# Processing Record 30 of Set 1 | saldanha
# Processing Record 31 of Set 1 | ekhabi
# Processing Record 32 of Set 1 | vostok
# Processing Record 33 of Set 1 | togur
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | key west
# Processing Record 38 of Set 1 | gunjur
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | erie
# Processing Record 42 of Set 1 | bogalusa
# Processing Record 43 of Set 1 | udupi
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | matai
# Processing Record 46 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 1 | kaseda
# Processing Record 48 of Set 1 | acapulco
# Processing Record 49 of Set 1 | maldonado
# Processing Record 50 of Set 1 | maymyo
# Processing Record 1 of Set 2 | san cristobal
# Processing Record 2 of Set 2 | segamat
# Processing Record 3 of Set 2 | komsomolskiy
# Processing Record 4 of Set 2 | amberley
# Processing Record 5 of Set 2 | te anau
# Processing Record 6 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | hailun
# Processing Record 9 of Set 2 | hilo
# Processing Record 10 of Set 2 | mar del plata
# Processing Record 11 of Set 2 | tamworth
# Processing Record 12 of Set 2 | dunedin
# Processing Record 13 of Set 2 | cockburn town
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | provideniya
# Processing Record 16 of Set 2 | belmonte
# Processing Record 17 of Set 2 | yendi
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | dingle
# Processing Record 20 of Set 2 | moree
# Processing Record 21 of Set 2 | port hardy
# Processing Record 22 of Set 2 | northam
# Processing Record 23 of Set 2 | buchanan
# Processing Record 24 of Set 2 | ponta do sol
# Processing Record 25 of Set 2 | flinders
# Processing Record 26 of Set 2 | urucui
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | vardo
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | hofn
# Processing Record 31 of Set 2 | lucea
# Processing Record 32 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 2 | jalu
# Processing Record 34 of Set 2 | lexington
# Processing Record 35 of Set 2 | kaitangata
# Processing Record 36 of Set 2 | luganville
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | kodiak
# Processing Record 39 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | rawson
# Processing Record 42 of Set 2 | paltinis
# Processing Record 43 of Set 2 | nanortalik
# Processing Record 44 of Set 2 | busselton
# Processing Record 45 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 2 | akonolinga
# Processing Record 49 of Set 2 | tsumeb
# Processing Record 50 of Set 2 | new norfolk
# Processing Record 1 of Set 3 | petrovskaya
# Processing Record 2 of Set 3 | nola
# Processing Record 3 of Set 3 | pauini
# Processing Record 4 of Set 3 | tuktoyaktuk
# Processing Record 5 of Set 3 | riyadh
# Processing Record 6 of Set 3 | safaga
# Processing Record 7 of Set 3 | kembe
# Processing Record 8 of Set 3 | castro
# Processing Record 9 of Set 3 | evensk
# Processing Record 10 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 3 | inhambane
# Processing Record 12 of Set 3 | labuhan
# Processing Record 13 of Set 3 | eureka
# Processing Record 14 of Set 3 | chuy
# Processing Record 15 of Set 3 | hazorasp
# Processing Record 16 of Set 3 | bambous virieux
# Processing Record 17 of Set 3 | saint-pierre
# Processing Record 18 of Set 3 | yuancheng
# Processing Record 19 of Set 3 | chicama
# Processing Record 20 of Set 3 | dikson
# Processing Record 21 of Set 3 | hobyo
# Processing Record 22 of Set 3 | kavaratti
# Processing Record 23 of Set 3 | constitucion
# Processing Record 24 of Set 3 | katsuura
# Processing Record 25 of Set 3 | saint george
# Processing Record 26 of Set 3 | camacha
# Processing Record 27 of Set 3 | semey
# Processing Record 28 of Set 3 | ixtapa
# Processing Record 29 of Set 3 | bethel
# Processing Record 30 of Set 3 | jeremie
# Processing Record 31 of Set 3 | huarmey
# Processing Record 32 of Set 3 | baker city
# Processing Record 33 of Set 3 | kruisfontein
# Processing Record 34 of Set 3 | longyearbyen
# Processing Record 35 of Set 3 | wilmington
# Processing Record 36 of Set 3 | reconquista
# Processing Record 37 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 3 | yueyang
# Processing Record 39 of Set 3 | morant bay
# Processing Record 40 of Set 3 | bluff
# Processing Record 41 of Set 3 | sorland
# Processing Record 42 of Set 3 | mayahi
# Processing Record 43 of Set 3 | ancud
# Processing Record 44 of Set 3 | qaanaaq
# Processing Record 45 of Set 3 | xai-xai
# Processing Record 46 of Set 3 | luena
# Processing Record 47 of Set 3 | basco
# Processing Record 48 of Set 3 | waitati
# Processing Record 49 of Set 3 | palghar
# Processing Record 50 of Set 3 | cabo san lucas
# Processing Record 1 of Set 4 | chukhloma
# Processing Record 2 of Set 4 | klaksvik
# Processing Record 3 of Set 4 | dong hoi
# Processing Record 4 of Set 4 | severo-kurilsk
# Processing Record 5 of Set 4 | butaritari
# Processing Record 6 of Set 4 | jamestown
# Processing Record 7 of Set 4 | necochea
# Processing Record 8 of Set 4 | san buenaventura
# Processing Record 9 of Set 4 | waipawa
# Processing Record 10 of Set 4 | lorengau
# Processing Record 11 of Set 4 | miri
# Processing Record 12 of Set 4 | suntar
# Processing Record 13 of Set 4 | cidreira
# Processing Record 14 of Set 4 | soe
# Processing Record 15 of Set 4 | sakakah
# Processing Record 16 of Set 4 | lebu
# Processing Record 17 of Set 4 | decatur
# Processing Record 18 of Set 4 | los andes
# Processing Record 19 of Set 4 | vieux-habitants
# Processing Record 20 of Set 4 | iqaluit
# Processing Record 21 of Set 4 | saint-augustin
# Processing Record 22 of Set 4 | portland
# Processing Record 23 of Set 4 | norman wells
# Processing Record 24 of Set 4 | bandar-e lengeh
# Processing Record 25 of Set 4 | chhindwara
# Processing Record 26 of Set 4 | san vicente
# Processing Record 27 of Set 4 | baglung
# Processing Record 28 of Set 4 | sinop
# Processing Record 29 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 4 | cabedelo
# Processing Record 31 of Set 4 | tuy hoa
# Processing Record 32 of Set 4 | torbay
# Processing Record 33 of Set 4 | geraldton
# Processing Record 34 of Set 4 | port elizabeth
# Processing Record 35 of Set 4 | torbat-e jam
# Processing Record 36 of Set 4 | fortuna
# Processing Record 37 of Set 4 | kilindoni
# Processing Record 38 of Set 4 | mount isa
# Processing Record 39 of Set 4 | ron phibun
# Processing Record 40 of Set 4 | kapit
# Processing Record 41 of Set 4 | naze
# Processing Record 42 of Set 4 | pimenta bueno
# Processing Record 43 of Set 4 | algiers
# Processing Record 44 of Set 4 | talnakh
# Processing Record 45 of Set 4 | isla mujeres
# Processing Record 46 of Set 4 | pacific grove
# Processing Record 47 of Set 4 | xining
# Processing Record 48 of Set 4 | porto novo
# Processing Record 49 of Set 4 | port hedland
# Processing Record 50 of Set 4 | riohacha
# Processing Record 1 of Set 5 | port lincoln
# Processing Record 2 of Set 5 | peniche
# Processing Record 3 of Set 5 | ugoofaaru
# Processing Record 4 of Set 5 | gat
# Processing Record 5 of Set 5 | nouadhibou
# Processing Record 6 of Set 5 | salar
# Processing Record 7 of Set 5 | isangel
# Processing Record 8 of Set 5 | escarcega
# Processing Record 9 of Set 5 | victoria
# Processing Record 10 of Set 5 | aklavik
# Processing Record 11 of Set 5 | jurm
# Processing Record 12 of Set 5 | bengkulu
# Processing Record 13 of Set 5 | ambilobe
# Processing Record 14 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 5 | ondangwa
# Processing Record 16 of Set 5 | salalah
# Processing Record 17 of Set 5 | kazanskaya
# Processing Record 18 of Set 5 | hirara
# Processing Record 19 of Set 5 | lobau
# Processing Record 20 of Set 5 | prince rupert
# Processing Record 21 of Set 5 | mackay
# Processing Record 22 of Set 5 | igunga
# Processing Record 23 of Set 5 | tiksi
# Processing Record 24 of Set 5 | pisco
# Processing Record 25 of Set 5 | tabora
# Processing Record 26 of Set 5 | suhbaatar
# Processing Record 27 of Set 5 | carnarvon
# Processing Record 28 of Set 5 | port-gentil
# Processing Record 29 of Set 5 | kasongo-lunda
# Processing Record 30 of Set 5 | lushunkou
# City not found. Skipping...
# Processing Record 31 of Set 5 | faya
# Processing Record 32 of Set 5 | hervey bay
# Processing Record 33 of Set 5 | aksarka
# Processing Record 34 of Set 5 | sitka
# Processing Record 35 of Set 5 | pitimbu
# Processing Record 36 of Set 5 | mamallapuram
# Processing Record 37 of Set 5 | tagusao
# Processing Record 38 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 5 | saskylakh
# Processing Record 40 of Set 5 | shubarkuduk
# Processing Record 41 of Set 5 | nador
# Processing Record 42 of Set 5 | yarmouth
# Processing Record 43 of Set 5 | saint-francois
# Processing Record 44 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 45 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 46 of Set 5 | darnah
# Processing Record 47 of Set 5 | upernavik
# Processing Record 48 of Set 5 | salinopolis
# Processing Record 49 of Set 5 | porto nacional
# Processing Record 50 of Set 5 | murray bridge
# Processing Record 1 of Set 6 | chegutu
# Processing Record 2 of Set 6 | wajir
# Processing Record 3 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 4 of Set 6 | tuatapere
# Processing Record 5 of Set 6 | chokurdakh
# Processing Record 6 of Set 6 | bathsheba
# Processing Record 7 of Set 6 | airai
# Processing Record 8 of Set 6 | cap malheureux
# Processing Record 9 of Set 6 | karmana
# City not found. Skipping...
# Processing Record 10 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 6 | bandarbeyla
# Processing Record 12 of Set 6 | srednekolymsk
# Processing Record 13 of Set 6 | mudanya
# Processing Record 14 of Set 6 | gizo
# Processing Record 15 of Set 6 | la ronge
# Processing Record 16 of Set 6 | vestmannaeyjar
# Processing Record 17 of Set 6 | kysyl-syr
# Processing Record 18 of Set 6 | barrow
# Processing Record 19 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 20 of Set 6 | lesnoye
# Processing Record 21 of Set 6 | korla
# Processing Record 22 of Set 6 | buin
# Processing Record 23 of Set 6 | ekibastuz
# Processing Record 24 of Set 6 | shelburne
# Processing Record 25 of Set 6 | oktyabrskiy
# Processing Record 26 of Set 6 | cherskiy
# Processing Record 27 of Set 6 | esperance
# Processing Record 28 of Set 6 | tougan
# Processing Record 29 of Set 6 | ishinomaki
# Processing Record 30 of Set 6 | quatre cocos
# Processing Record 31 of Set 6 | qrendi
# Processing Record 32 of Set 6 | zhigansk
# Processing Record 33 of Set 6 | hualmay
# Processing Record 34 of Set 6 | lodja
# Processing Record 35 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 37 of Set 6 | vanavara
# Processing Record 38 of Set 6 | margate
# Processing Record 39 of Set 6 | banda aceh
# Processing Record 40 of Set 6 | timizart
# Processing Record 41 of Set 6 | vrangel
# Processing Record 42 of Set 6 | markova
# Processing Record 43 of Set 6 | mayo
# Processing Record 44 of Set 6 | san quintin
# Processing Record 45 of Set 6 | khorramshahr
# Processing Record 46 of Set 6 | marsh harbour
# Processing Record 47 of Set 6 | surovatikha
# Processing Record 48 of Set 6 | morros
# Processing Record 49 of Set 6 | husavik
# Processing Record 50 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 7 | hami
# Processing Record 2 of Set 7 | lisala
# Processing Record 3 of Set 7 | makakilo city
# Processing Record 4 of Set 7 | hithadhoo
# Processing Record 5 of Set 7 | xuddur
# Processing Record 6 of Set 7 | swellendam
# Processing Record 7 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 7 | college
# Processing Record 9 of Set 7 | henties bay
# Processing Record 10 of Set 7 | luderitz
# Processing Record 11 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 12 of Set 7 | west bay
# Processing Record 13 of Set 7 | krasnokholm
# Processing Record 14 of Set 7 | kenai
# Processing Record 15 of Set 7 | caramay
# Processing Record 16 of Set 7 | parkersburg
# Processing Record 17 of Set 7 | la orilla
# Processing Record 18 of Set 7 | gunnedah
# Processing Record 19 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 20 of Set 7 | vao
# Processing Record 21 of Set 7 | westport
# Processing Record 22 of Set 7 | padang
# Processing Record 23 of Set 7 | quesnel
# Processing Record 24 of Set 7 | carpinteria
# Processing Record 25 of Set 7 | kishtwar
# Processing Record 26 of Set 7 | yellowknife
# Processing Record 27 of Set 7 | taoudenni
# Processing Record 28 of Set 7 | whitehorse
# Processing Record 29 of Set 7 | hornepayne
# Processing Record 30 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 31 of Set 7 | acara
# Processing Record 32 of Set 7 | narrabri
# Processing Record 33 of Set 7 | vanersborg
# Processing Record 34 of Set 7 | lat yao
# Processing Record 35 of Set 7 | adre
# Processing Record 36 of Set 7 | preobrazheniye
# Processing Record 37 of Set 7 | arman
# Processing Record 38 of Set 7 | caninde de sao francisco
# Processing Record 39 of Set 7 | nelson bay
# Processing Record 40 of Set 7 | idlib
# Processing Record 41 of Set 7 | ossora
# Processing Record 42 of Set 7 | sao filipe
# Processing Record 43 of Set 7 | ahipara
# Processing Record 44 of Set 7 | ayan
# Processing Record 45 of Set 7 | cauquenes
# Processing Record 46 of Set 7 | hasaki
# Processing Record 47 of Set 7 | hurricane
# Processing Record 48 of Set 7 | matay
# Processing Record 49 of Set 7 | ilebo
# Processing Record 50 of Set 7 | pevek
# Processing Record 1 of Set 8 | cam pha
# City not found. Skipping...
# Processing Record 2 of Set 8 | eugene
# Processing Record 3 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 4 of Set 8 | grammichele
# Processing Record 5 of Set 8 | kells
# Processing Record 6 of Set 8 | brainerd
# Processing Record 7 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 8 of Set 8 | anori
# Processing Record 9 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 10 of Set 8 | bonthe
# Processing Record 11 of Set 8 | fayaoue
# Processing Record 12 of Set 8 | barra patuca
# Processing Record 13 of Set 8 | roald
# Processing Record 14 of Set 8 | okhotsk
# Processing Record 15 of Set 8 | lasa
# Processing Record 16 of Set 8 | guerrero negro
# Processing Record 17 of Set 8 | syzran
# Processing Record 18 of Set 8 | tigzirt
# Processing Record 19 of Set 8 | miranda
# Processing Record 20 of Set 8 | velyka oleksandrivka
# Processing Record 21 of Set 8 | rundu
# Processing Record 22 of Set 8 | eston
# Processing Record 23 of Set 8 | saint anthony
# Processing Record 24 of Set 8 | dajabon
# Processing Record 25 of Set 8 | alofi
# Processing Record 26 of Set 8 | pilar
# Processing Record 27 of Set 8 | zyryanka
# Processing Record 28 of Set 8 | san carlos de bariloche
# Processing Record 29 of Set 8 | sibolga
# Processing Record 30 of Set 8 | ullapool
# Processing Record 31 of Set 8 | daxian
# City not found. Skipping...
# Processing Record 32 of Set 8 | menongue
# Processing Record 33 of Set 8 | pangnirtung
# Processing Record 34 of Set 8 | hamilton
# Processing Record 35 of Set 8 | dubai
# Processing Record 36 of Set 8 | palmer
# Processing Record 37 of Set 8 | tornio
# Processing Record 38 of Set 8 | upata
# Processing Record 39 of Set 8 | miandrivazo
# Processing Record 40 of Set 8 | luanda
# Processing Record 41 of Set 8 | wladyslawowo
# Processing Record 42 of Set 8 | gorontalo
# Processing Record 43 of Set 8 | igarape-acu
# City not found. Skipping...
# Processing Record 44 of Set 8 | dyersburg
# Processing Record 45 of Set 8 | perth
# Processing Record 46 of Set 8 | elizabeth city
# Processing Record 47 of Set 8 | faanui
# Processing Record 48 of Set 8 | mayfield heights
# Processing Record 49 of Set 8 | nhulunbuy
# Processing Record 50 of Set 8 | galway
# Processing Record 1 of Set 9 | danilov
# Processing Record 2 of Set 9 | baykit
# Processing Record 3 of Set 9 | kasempa
# Processing Record 4 of Set 9 | sabang
# Processing Record 5 of Set 9 | batagay-alyta
# Processing Record 6 of Set 9 | egvekinot
# Processing Record 7 of Set 9 | springdale
# Processing Record 8 of Set 9 | craig
# Processing Record 9 of Set 9 | labuan
# Processing Record 10 of Set 9 | casma
# Processing Record 11 of Set 9 | atikokan
# Processing Record 12 of Set 9 | touros
# Processing Record 13 of Set 9 | yangmei
# Processing Record 14 of Set 9 | palakollu
# Processing Record 15 of Set 9 | fomboni
# Processing Record 16 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 9 | almansa
# Processing Record 18 of Set 9 | benjamin hill
# Processing Record 19 of Set 9 | sijunjung
# Processing Record 20 of Set 9 | christchurch
# Processing Record 21 of Set 9 | santa maria
# Processing Record 22 of Set 9 | bassila
# Processing Record 23 of Set 9 | tabou
# Processing Record 24 of Set 9 | axim
# Processing Record 25 of Set 9 | aldan
# Processing Record 26 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 9 | kindu
# Processing Record 28 of Set 9 | caluluan
# City not found. Skipping...
# Processing Record 29 of Set 9 | los alamos
# Processing Record 30 of Set 9 | araguacu
# Processing Record 31 of Set 9 | kismayo
# Processing Record 32 of Set 9 | novyy urengoy
# Processing Record 33 of Set 9 | cayenne
# Processing Record 34 of Set 9 | muravlenko
# Processing Record 35 of Set 9 | vilyuysk
# Processing Record 36 of Set 9 | bani
# Processing Record 37 of Set 9 | lavrentiya
# Processing Record 38 of Set 9 | ewa beach
# Processing Record 39 of Set 9 | barquisimeto
# Processing Record 40 of Set 9 | tukrah
# Processing Record 41 of Set 9 | manaure
# Processing Record 42 of Set 9 | sisimiut
# Processing Record 43 of Set 9 | berlevag
# Processing Record 44 of Set 9 | nibe
# Processing Record 45 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 9 | kahului
# Processing Record 47 of Set 9 | alta floresta
# Processing Record 48 of Set 9 | verkhoyansk
# Processing Record 49 of Set 9 | aberdeen
# Processing Record 50 of Set 9 | concepcion del oro
# Processing Record 1 of Set 10 | vanimo
# Processing Record 2 of Set 10 | san martin
# Processing Record 3 of Set 10 | mirador
# Processing Record 4 of Set 10 | bayir
# Processing Record 5 of Set 10 | racale
# Processing Record 6 of Set 10 | moose factory
# Processing Record 7 of Set 10 | villanueva de la serena
# Processing Record 8 of Set 10 | port blair
# Processing Record 9 of Set 10 | toora-khem
# Processing Record 10 of Set 10 | puerto escondido
# Processing Record 11 of Set 10 | andenes
# Processing Record 12 of Set 10 | miajadas
# Processing Record 13 of Set 10 | honiara
# Processing Record 14 of Set 10 | souillac
# Processing Record 15 of Set 10 | socorro
# Processing Record 16 of Set 10 | milkovo
# Processing Record 17 of Set 10 | katangli
# Processing Record 18 of Set 10 | wittmund
# Processing Record 19 of Set 10 | mocuba
# Processing Record 20 of Set 10 | tanout
# Processing Record 21 of Set 10 | cap-aux-meules
# Processing Record 22 of Set 10 | fillan
# Processing Record 23 of Set 10 | nuevitas
# Processing Record 24 of Set 10 | valentin gomez farias
# Processing Record 25 of Set 10 | khudumelapye
# Processing Record 26 of Set 10 | bilibino
# Processing Record 27 of Set 10 | laem sing
# Processing Record 28 of Set 10 | chetumal
# Processing Record 29 of Set 10 | alyangula
# Processing Record 30 of Set 10 | coatzintla
# Processing Record 31 of Set 10 | bethanien
# Processing Record 32 of Set 10 | tianpeng
# Processing Record 33 of Set 10 | conway
# Processing Record 34 of Set 10 | arrecife
# Processing Record 35 of Set 10 | urumqi
# Processing Record 36 of Set 10 | carthage
# Processing Record 37 of Set 10 | san borja
# Processing Record 38 of Set 10 | galle
# Processing Record 39 of Set 10 | grand-santi
# Processing Record 40 of Set 10 | sambava
# Processing Record 41 of Set 10 | narsaq
# Processing Record 42 of Set 10 | phalaborwa
# Processing Record 43 of Set 10 | avera
# Processing Record 44 of Set 10 | huamuxtitlan
# Processing Record 45 of Set 10 | broken hill
# Processing Record 46 of Set 10 | shingu
# Processing Record 47 of Set 10 | sinegorye
# Processing Record 48 of Set 10 | yerofey pavlovich
# Processing Record 49 of Set 10 | londiani
# Processing Record 50 of Set 10 | ipixuna
# Processing Record 1 of Set 11 | viedma
# Processing Record 2 of Set 11 | tezu
# Processing Record 3 of Set 11 | byron bay
# Processing Record 4 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 5 of Set 11 | keti bandar
# Processing Record 6 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 8 of Set 11 | turukhansk
# Processing Record 9 of Set 11 | alexandroupoli
# Processing Record 10 of Set 11 | chapais
# Processing Record 11 of Set 11 | catamarca
# Processing Record 12 of Set 11 | nizhnyaya tavda
# Processing Record 13 of Set 11 | bakchar
# Processing Record 14 of Set 11 | reshetylivka
# Processing Record 15 of Set 11 | chabahar
# Processing Record 16 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 11 | ust-kuyga
# Processing Record 19 of Set 11 | fonte boa
# Processing Record 20 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 21 of Set 11 | kodino
# Processing Record 22 of Set 11 | clyde river
# Processing Record 23 of Set 11 | lamu
# Processing Record 24 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 25 of Set 11 | syracuse
# Processing Record 26 of Set 11 | lashio
# Processing Record 27 of Set 11 | codrington
# Processing Record 28 of Set 11 | kalmunai
# Processing Record 29 of Set 11 | laurinburg
# Processing Record 30 of Set 11 | sokoto
# Processing Record 31 of Set 11 | pocone
# Processing Record 32 of Set 11 | grindavik
# Processing Record 33 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 34 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 11 | pathein
# Processing Record 36 of Set 11 | mandalgovi
# Processing Record 37 of Set 11 | charlottesville
# Processing Record 38 of Set 11 | mana
# Processing Record 39 of Set 11 | mahebourg
# Processing Record 40 of Set 11 | ahuimanu
# Processing Record 41 of Set 11 | santa marta
# Processing Record 42 of Set 11 | thinadhoo
# Processing Record 43 of Set 11 | itarema
# Processing Record 44 of Set 11 | liku
# Processing Record 45 of Set 11 | road town
# Processing Record 46 of Set 11 | sumbe
# Processing Record 47 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 11 | rio gallegos
# Processing Record 49 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 50 of Set 11 | pangkalanbuun
# Processing Record 1 of Set 12 | el alto
# Processing Record 2 of Set 12 | yumen
# Processing Record 3 of Set 12 | yar-sale
# Processing Record 4 of Set 12 | dien bien
# City not found. Skipping...
# Processing Record 5 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 6 of Set 12 | adrar
# Processing Record 7 of Set 12 | balabac
# Processing Record 8 of Set 12 | japura
# Processing Record 9 of Set 12 | moron
# Processing Record 10 of Set 12 | praia da vitoria
# Processing Record 11 of Set 12 | humberto de campos
# Processing Record 12 of Set 12 | ahtopol
# Processing Record 13 of Set 12 | rabo de peixe
# Processing Record 14 of Set 12 | champerico
# Processing Record 15 of Set 12 | zykovo
# Processing Record 16 of Set 12 | madruga
# Processing Record 17 of Set 12 | eyl
# Processing Record 18 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 19 of Set 12 | tarko-sale
# Processing Record 20 of Set 12 | aborlan
# Processing Record 21 of Set 12 | methoni
# Processing Record 22 of Set 12 | kavieng
# Processing Record 23 of Set 12 | chumikan
# Processing Record 24 of Set 12 | pokhara
# Processing Record 25 of Set 12 | gohad
# Processing Record 26 of Set 12 | nerchinskiy zavod
# Processing Record 27 of Set 12 | tulum
# Processing Record 28 of Set 12 | port arthur
# Processing Record 29 of Set 12 | biak
# Processing Record 30 of Set 12 | le locle
# Processing Record 31 of Set 12 | tigil
# Processing Record 32 of Set 12 | rio claro
# Processing Record 33 of Set 12 | bamiantong
# Processing Record 34 of Set 12 | scalloway
# City not found. Skipping...
# Processing Record 35 of Set 12 | gobabis
# Processing Record 36 of Set 12 | mecca
# Processing Record 37 of Set 12 | tutoia
# Processing Record 38 of Set 12 | libenge
# Processing Record 39 of Set 12 | bay roberts
# Processing Record 40 of Set 12 | mehriz
# Processing Record 41 of Set 12 | bure
# Processing Record 42 of Set 12 | beringovskiy
# Processing Record 43 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 12 | majholi
# Processing Record 45 of Set 12 | lagoa
# Processing Record 46 of Set 12 | ndioum
# Processing Record 47 of Set 12 | ilula
# Processing Record 48 of Set 12 | amapa
# Processing Record 49 of Set 12 | carauari
# Processing Record 50 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 1 of Set 13 | lata
# Processing Record 2 of Set 13 | bollnas
# Processing Record 3 of Set 13 | bogale
# Processing Record 4 of Set 13 | kununurra
# Processing Record 5 of Set 13 | takoradi
# Processing Record 6 of Set 13 | vila franca do campo
# Processing Record 7 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 13 | blagoyevo
# Processing Record 9 of Set 13 | rotterdam
# Processing Record 10 of Set 13 | mackenzie
# Processing Record 11 of Set 13 | am timan
# Processing Record 12 of Set 13 | khetri
# Processing Record 13 of Set 13 | skagen
# Processing Record 14 of Set 13 | findochty
# Processing Record 15 of Set 13 | pindiga
# Processing Record 16 of Set 13 | palma
# Processing Record 17 of Set 13 | ilam
# Processing Record 18 of Set 13 | samarai
# Processing Record 19 of Set 13 | yulara
# Processing Record 20 of Set 13 | vangaindrano
# Processing Record 21 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 22 of Set 13 | sayyan
# Processing Record 23 of Set 13 | kulhudhuffushi
# Processing Record 24 of Set 13 | saint leonard
# Processing Record 25 of Set 13 | rorvik
# Processing Record 26 of Set 13 | mombetsu
# Processing Record 27 of Set 13 | bereda
# Processing Record 28 of Set 13 | ulladulla
# Processing Record 29 of Set 13 | skjervoy
# Processing Record 30 of Set 13 | the pas
# Processing Record 31 of Set 13 | tuensang
# Processing Record 32 of Set 13 | redding
# Processing Record 33 of Set 13 | desna
# Processing Record 34 of Set 13 | port keats
# Processing Record 35 of Set 13 | cam ranh
# Processing Record 36 of Set 13 | marrakesh
# Processing Record 37 of Set 13 | santa cruz
# Processing Record 38 of Set 13 | coquimbo
# Processing Record 39 of Set 13 | fairbanks
# Processing Record 40 of Set 13 | tahe
# Processing Record 41 of Set 13 | shu
# Processing Record 42 of Set 13 | mareeba
# Processing Record 43 of Set 13 | sucua
# Processing Record 44 of Set 13 | shahpur
# Processing Record 45 of Set 13 | nantucket
# Processing Record 46 of Set 13 | arlit
# Processing Record 47 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 13 | chico
# Processing Record 49 of Set 13 | awjilah
# Processing Record 50 of Set 13 | yenagoa
# Processing Record 1 of Set 14 | inuvik
# Processing Record 2 of Set 14 | yashkul
# Processing Record 3 of Set 14 | soyo
# Processing Record 4 of Set 14 | nome
# Processing Record 5 of Set 14 | capao da canoa
# Processing Record 6 of Set 14 | ilongero
# Processing Record 7 of Set 14 | dudinka
# Processing Record 8 of Set 14 | qaqortoq
# Processing Record 9 of Set 14 | carlisle
# Processing Record 10 of Set 14 | oksfjord
# Processing Record 11 of Set 14 | narasannapeta
# Processing Record 12 of Set 14 | yarada
# Processing Record 13 of Set 14 | paamiut
# Processing Record 14 of Set 14 | balcesti
# Processing Record 15 of Set 14 | rosetta
# Processing Record 16 of Set 14 | walvis bay
# Processing Record 17 of Set 14 | teguise
# Processing Record 18 of Set 14 | muros
# Processing Record 19 of Set 14 | buraydah
# Processing Record 20 of Set 14 | brae
# Processing Record 21 of Set 14 | chakia
# Processing Record 22 of Set 14 | puerto ayacucho
# Processing Record 23 of Set 14 | puerto pinasco
# City not found. Skipping...
# Processing Record 24 of Set 14 | saravan
# Processing Record 25 of Set 14 | sao jose da coroa grande
# Processing Record 26 of Set 14 | laurel
# Processing Record 27 of Set 14 | khani
# Processing Record 28 of Set 14 | madison
# Processing Record 29 of Set 14 | kandrian
# Processing Record 30 of Set 14 | sioux lookout
# Processing Record 31 of Set 14 | asau
# Processing Record 32 of Set 14 | cancun
# Processing Record 33 of Set 14 | lazaro cardenas
# Processing Record 34 of Set 14 | ales
# Processing Record 35 of Set 14 | bambanglipuro
# Processing Record 36 of Set 14 | colac
# Processing Record 37 of Set 14 | mitsamiouli
# Processing Record 38 of Set 14 | itaituba
# Processing Record 39 of Set 14 | honghu
# Processing Record 40 of Set 14 | pasni
# Processing Record 41 of Set 14 | kamsack
# Processing Record 42 of Set 14 | bubaque
# Processing Record 43 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 14 | kaeo
# Processing Record 45 of Set 14 | rio grande
# Processing Record 46 of Set 14 | ostersund
# Processing Record 47 of Set 14 | guilin
# Processing Record 48 of Set 14 | gongzhuling
# Processing Record 49 of Set 14 | gamba
# Processing Record 50 of Set 14 | benguela
# Processing Record 1 of Set 15 | polonnaruwa
# Processing Record 2 of Set 15 | laguna
# Processing Record 3 of Set 15 | marawi
# Processing Record 4 of Set 15 | santa margherita ligure
# Processing Record 5 of Set 15 | maragogi
# Processing Record 6 of Set 15 | los llanos de aridane
# Processing Record 7 of Set 15 | tautira
# Processing Record 8 of Set 15 | mount holly
# Processing Record 9 of Set 15 | hailar
# Processing Record 10 of Set 15 | beeville
# Processing Record 11 of Set 15 | zhanakorgan
# Processing Record 12 of Set 15 | jurilovca
# Processing Record 13 of Set 15 | rutul
# Processing Record 14 of Set 15 | achit
# Processing Record 15 of Set 15 | dhone
# Processing Record 16 of Set 15 | morehead
# Processing Record 17 of Set 15 | muisne
# Processing Record 18 of Set 15 | cornelio procopio
# Processing Record 19 of Set 15 | namibe
# Processing Record 20 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 21 of Set 15 | calama
# Processing Record 22 of Set 15 | maningrida
# Processing Record 23 of Set 15 | lakes entrance
# Processing Record 24 of Set 15 | mongo
# Processing Record 25 of Set 15 | itapaci
# Processing Record 26 of Set 15 | innisfail
# Processing Record 27 of Set 15 | damietta
# Processing Record 28 of Set 15 | svetlogorsk
# Processing Record 29 of Set 15 | strezhevoy
# Processing Record 30 of Set 15 | majene
# Processing Record 31 of Set 15 | kropotkin
# Processing Record 32 of Set 15 | el dorado
# Processing Record 33 of Set 15 | fiumicino
# Processing Record 34 of Set 15 | pochutla
# Processing Record 35 of Set 15 | tocoa
# Processing Record 36 of Set 15 | mpulungu
# Processing Record 37 of Set 15 | black river
# Processing Record 38 of Set 15 | aswan
# Processing Record 39 of Set 15 | tymovskoye
# Processing Record 40 of Set 15 | sur
# Processing Record 41 of Set 15 | telgte
# Processing Record 42 of Set 15 | mansa
# Processing Record 43 of Set 15 | kabanjahe
# Processing Record 44 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 45 of Set 15 | verkhnyaya inta
# Processing Record 46 of Set 15 | royan
# Processing Record 47 of Set 15 | matagami
# Processing Record 48 of Set 15 | belle fourche
# Processing Record 49 of Set 15 | inverness
# Processing Record 50 of Set 15 | vila velha
# Processing Record 1 of Set 16 | thai binh
# Processing Record 2 of Set 16 | istisu
# Processing Record 3 of Set 16 | mgandu
# Processing Record 4 of Set 16 | mutsu
# Processing Record 5 of Set 16 | abonnema
# Processing Record 6 of Set 16 | bantva
# Processing Record 7 of Set 16 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 16 | general pico
# Processing Record 9 of Set 16 | tevriz
# Processing Record 10 of Set 16 | khalimbekaul
# Processing Record 11 of Set 16 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 16 | karamay
# City not found. Skipping...
# Processing Record 13 of Set 16 | olden
# Processing Record 14 of Set 16 | borgarnes
# Processing Record 15 of Set 16 | enshi
# Processing Record 16 of Set 16 | scarborough
# Processing Record 17 of Set 16 | hambantota
# Processing Record 18 of Set 16 | chibuto
# Processing Record 19 of Set 16 | raudeberg
# Processing Record 20 of Set 16 | coari
# Processing Record 21 of Set 16 | wanning
# Processing Record 22 of Set 16 | nizhniy tsasuchey
# Processing Record 23 of Set 16 | barcelos
# Processing Record 24 of Set 16 | caravelas
# Processing Record 25 of Set 16 | lompoc
# Processing Record 26 of Set 16 | kurumkan
# Processing Record 27 of Set 16 | islampur
# Processing Record 28 of Set 16 | san rafael
# Processing Record 29 of Set 16 | zhanaozen
# Processing Record 30 of Set 16 | bondo
# Processing Record 31 of Set 16 | san blas
# Processing Record 32 of Set 16 | caxito
# Processing Record 33 of Set 16 | livani
# ----------------------------------
# Data Retrieval Complete
# ----------------------------------

# %%
# Add data to a new DataFrame and export as a csv file.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Annau      TM  37.89   58.52     69.80        35           0
# 1      Rikitea      PF -23.12 -134.97     69.28        66           0
# 2      Kuching      MY   1.55  110.33     77.00        94          20
# 3       Hobart      AU -42.88  147.33     57.99        58          75
# 4      Ushuaia      AR -54.80  -68.30     33.80        94          90
# 5  Stutterheim      ZA -32.57   27.42     43.63        83          48
# 6     Hermanus      ZA -34.42   19.23     48.00        90          37
# 7   High Level      CA  58.52 -117.14     60.80        77          75
# 8    Ostrovnoy      RU  68.05   39.51     48.58        66          74
# 9       Tiarei      PF -17.53 -149.33     82.40        65          20
#
#    Wind Speed Current Description
# 0        4.70           clear sky
# 1        5.77           clear sky
# 2        2.24          few clouds
# 3       13.87       broken clouds
# 4       11.41          light snow
# 5        3.42    scattered clouds
# 6        4.00       moderate rain
# 7       14.99       broken clouds
# 8       11.43       broken clouds
# 9       10.29          few clouds

# %%
# Export the city_data DataFrame to a csv file.
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
len(city_data)
# Out:
# 718
